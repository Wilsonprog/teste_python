# %%
a = 3
b = 2
print(a + b)
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel) (demo.ipynb)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:e3f7bbf9-a064-4179-8085-d8622e04ecaf

# %%
3 * 0.1
